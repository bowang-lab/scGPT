# %%
import os
from pathlib import Path

import numpy as np
import scanpy as sc
import faiss

from build_atlas_index_faiss import load_index

# %% [markdown]
# You can find the code to build the index at [build_atlas_index_faiss.py](build_atlas_index_faiss.py).
# We applied careful tuning to finally very well balance between the accuracy and efficiency. Now the actual building process takes less than 3 minutes and we choose to use only 16 bytes to store the vector per cell, which leads to 936 MB for the whole index of around 40 million cells.

# %%
use_gpu = faiss.get_num_gpus() > 0
index, meta_labels = load_index(
    index_dir="/scratch/hdd001/home/haotian/projects/cellxemb/all",
    use_config_file=False,
    use_gpu=use_gpu,
)
print(f"Loaded index with {index.ntotal} cells")
if isinstance(meta_labels[0], bytes):
    meta_labels = meta_labels.astype(str)
# Out:
# Loading index and meta from /scratch/hdd001/home/haotian/projects/cellxemb/all ...
# Index loaded, num_embeddings: 40628904
# Set nprobe from 128 to 128 for 16384 clusters
# Loaded index with 40628904 cells

# %% [markdown]
# ## ways to reduce the memory footprint of the index
#
# 1. use smaller feature dimensions. Create an autoencoder or PCA before indexing? An issue with the projection will need to be updated now and then when a large trunk of new data is added to the atlas.
#
#     1.1. Also, if using PCA, be aware that the different dimensions can have different variance scales. So it is important to use a distance metric such as l2 instead of cosine.
#
# 2. use smaller number of cells, such as meta cells. A naive way to select meta cells is to do an stratified sampling of the cells of different cell types in the atlas. The strategy can be tricky and will need to be updated when new data is added as well.
#
#     2.1 On one hand, using some meta cells may be needed. Since there can be too many cells, we want the found K neighbors to be representative enough, like they can cover enough range in the cell space. To make this more clear, some area in the cell space may be too dense comparing to other areas, this will make it an unfair higher chance of selecting cells in the region. So basically too approaches to relieve this (1) selecting meta cells more evenly spread, and then just retrieve in some meta cell space. (2) Post processing like normalized voting across cell types. A summarizing point is as follows, even if you want to use the approach (2), one will still need approach (1) because you will at least need cell states that should be covered actually get covered, so that then they can be re weighted during the voting process.
#
#     2.2 Using stratified sampling by annotated cell types is not appropriate, since the annotation schema can definitely change over time. So really need to make sure the meta cell selection is simply dependent on the raw data themselves.
#
#     2.3 Can think about using some layers of the hnswlib index as meta cells.

# %%
# QUERY
query_data_dir = "/scratch/ssd004/datasets/cellxgene/embed_dataset/ms-dataset/"
# get all file under this dir
query_data_path_list = os.listdir(query_data_dir)
# query_data_path_list = [os.path.join(query_data_dir, i) for i in query_data_path_list]
query_data_path_list = [
    os.path.join(query_data_dir, i) for i in query_data_path_list if "embed_0" in i
]
query_data_path_list
# Out:
# ['/scratch/ssd004/datasets/cellxgene/embed_dataset/ms-dataset/embed_0.h5ad']

# %% [markdown]
# Another point is that when computing the retrieving process. Balancing the voting process by considering the different numbers of cells for each cell is essential. Maybe the voting weights can be normalized by the ratio of cells in the atlas. Also please have a look at existing literature about how they applied that.

# %%
query_embed_list = []
query_meta_list = []
for query_data_path in query_data_path_list:
    data = sc.read_h5ad(query_data_path)
    query_embed_list.append(data.X)
    query_meta_list.append(data.obs["cell_type"].values)
    
query_embed_array = np.concatenate(query_embed_list, axis=0)
query_meta_array = np.concatenate(query_meta_list, axis=0)

# %% [markdown]
# The search runs remarkably fast. Using GPU, the following search for 10,000 queries from the whole 40-million cell index typically takes less than 1 second.

# %%
k = 1000
# test with the first 100 cells
# %time distances, idx = index.search(query_embed_array[:10000], k)
gt = query_meta_array[:10000]
# Out:
# CPU times: user 846 ms, sys: 581 ms, total: 1.43 s
# Wall time: 761 ms

# %%
matched_array = meta_labels[idx]
from scipy.stats import mode

voting = mode(matched_array, axis=1)[0]

# %% [markdown]
# ### TODO: need a weighted voting to balance the different ratio of celltypes in the reference atlas

# %%
voting[:10]
# Out:
# array([['oligodendrocyte'],
#        ['double-positive, alpha-beta thymocyte'],
#        ['OFF-bipolar cell'],
#        ['oligodendrocyte'],
#        ['ON-bipolar cell'],
#        ['ON-bipolar cell'],
#        ['oligodendrocyte'],
#        ['double-positive, alpha-beta thymocyte'],
#        ['astrocyte'],
#        ['oligodendrocyte']], dtype='<U84')

# %%
gt[:10]
# Out:
# array(['oligodendrocyte A', 'PVALB-expressing interneuron',
#        'oligodendrocyte A', 'oligodendrocyte precursor cell',
#        'oligodendrocyte A', 'mixed glial cell?', 'mixed glial cell?',
#        'VIP-expressing interneuron', 'astrocyte',
#        'oligodendrocyte precursor cell'], dtype=object)

# %%
matched_array[0]
# Out:
# array(['cardiac muscle cell', 'double-positive, alpha-beta thymocyte',
#        'cardiac muscle cell', 'epithelial cell',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule',
#        'double-positive, alpha-beta thymocyte', 'mural cell',
#        'CD4-positive, alpha-beta T cell',
#        'CD4-positive, alpha-beta T cell',
#        'cortical cell of adrenal gland', 'cardiac muscle cell',
#        'mural cell', 'stromal cell',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'epithelial cell of proximal tubule',
#        'cortical cell of adrenal gland', 'alpha-beta T cell',
#        'cortical cell of adrenal gland', 'stromal cell',
#        'double-positive, alpha-beta thymocyte',
#        'cortical cell of adrenal gland',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'enterocyte', 'double negative thymocyte', 'oligodendrocyte',
#        'cardiac muscle cell', 'endocardial cell', 'native cell',
#        'endocardial cell', 'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule', 'GABAergic neuron',
#        'GABAergic neuron', 'cardiac muscle cell', 'cardiac muscle cell',
#        'cardiac muscle cell', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'CD4-positive, alpha-beta T cell', 'alpha-beta T cell',
#        'cardiac muscle cell', 'cardiac muscle cell', 'stromal cell',
#        'double-positive, alpha-beta thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'cardiac muscle cell', 'oligodendrocyte', 'native cell',
#        'Schwann cell', 'oligodendrocyte', 'oligodendrocyte',
#        'cortical cell of adrenal gland', 'fibroblast', 'contractile cell',
#        'epithelial cell', 'mural cell',
#        'double-positive, alpha-beta thymocyte', 'Schwann cell',
#        'double-positive, alpha-beta thymocyte', 'stromal cell',
#        'glutamatergic neuron', 'neuroendocrine cell',
#        'cardiac muscle cell', 'smooth muscle cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'neuroendocrine cell', 'neuroendocrine cell', 'epithelial cell',
#        'regulatory T cell', 'epicardial adipocyte', 'mural cell',
#        'macrophage', 'stromal cell', 'endocardial cell',
#        'oligodendrocyte', 'oligodendrocyte', 'glial cell', 'glial cell',
#        'cardiac muscle cell',
#        'epithelial cell of lower respiratory tract',
#        'cortical cell of adrenal gland', 'mural cell',
#        'cardiac muscle cell', 'plasma cell', 'thymocyte',
#        'primordial germ cell', 'stromal cell',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of lower respiratory tract',
#        'cardiac muscle cell', 'retinal rod cell',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract',
#        'epicardial adipocyte', 'double-positive, alpha-beta thymocyte',
#        'GABAergic neuron', 'double-positive, alpha-beta thymocyte',
#        'stromal cell', 'enterocyte', 'cardiac muscle cell',
#        'oligodendrocyte', 'oligodendrocyte', 'cardiac muscle cell',
#        'cortical cell of adrenal gland',
#        'epithelial cell of lower respiratory tract',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'contractile cell',
#        'stromal cell', 'stromal cell',
#        'double-positive, alpha-beta thymocyte',
#        'double negative thymocyte', 'stromal cell', 'stromal cell',
#        'smooth muscle cell', 'stromal cell',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule', 'alpha-beta T cell',
#        'oligodendrocyte', 'erythroblast',
#        'double-positive, alpha-beta thymocyte',
#        'cortical cell of adrenal gland', 'cardiac muscle cell',
#        'stromal cell', 'stromal cell',
#        'central nervous system macrophage', 'oligodendrocyte',
#        'oligodendrocyte', 'cardiac muscle cell', 'oligodendrocyte',
#        'oligodendrocyte', 'epithelial cell of lower respiratory tract',
#        'cardiac muscle cell', 'stromal cell',
#        'double-positive, alpha-beta thymocyte', 'epithelial cell',
#        'oligodendrocyte', 'endocardial cell', 'epithelial cell',
#        'double-positive, alpha-beta thymocyte', 'stromal cell',
#        'stromal cell', 'CD8-positive, alpha-beta T cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'endocardial cell', 'thymocyte', 'glutamatergic neuron',
#        'glutamatergic neuron', 'epicardial adipocyte',
#        'double-positive, alpha-beta thymocyte', 'type II pneumocyte',
#        'oligodendrocyte', 'double-positive, alpha-beta thymocyte',
#        'central nervous system macrophage', 'oligodendrocyte',
#        'cardiac muscle cell', 'oligodendrocyte', 'thymocyte',
#        'oligodendrocyte', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'macrophage', 'thymocyte', 'stromal cell', 'cardiac muscle cell',
#        'endocardial cell', 'endothelial cell of vascular tree',
#        'cardiac muscle cell', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'cortical cell of adrenal gland', 'cardiac muscle cell',
#        'GABAergic neuron', 'double-positive, alpha-beta thymocyte',
#        'thymocyte', 'stromal cell', 'epithelial cell',
#        'type B pancreatic cell',
#        'enterocyte of epithelium of large intestine', 'oligodendrocyte',
#        'glutamatergic neuron', 'CD8-positive, alpha-beta T cell',
#        'stromal cell', 'double-positive, alpha-beta thymocyte',
#        'stromal cell', 'epithelial cell of exocrine pancreas',
#        'epithelial cell of lower respiratory tract',
#        'cardiac muscle cell', 'endothelial cell of vascular tree',
#        'alpha-beta T cell', 'thymocyte', 'glutamatergic neuron',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'type B pancreatic cell',
#        'cardiac muscle cell', 'double-positive, alpha-beta thymocyte',
#        'thymocyte', 'mural cell', 'double-positive, alpha-beta thymocyte',
#        'stromal cell', 'retina horizontal cell',
#        'double-positive, alpha-beta thymocyte', 'mural cell',
#        'double negative thymocyte', 'stromal cell', 'stromal cell',
#        'stromal cell', 'cortical cell of adrenal gland',
#        'epicardial adipocyte', 'double negative thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'CD8-positive, alpha-beta T cell',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule', 'capillary endothelial cell',
#        'cortical cell of adrenal gland', 'mural cell', 'myeloid cell',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'oligodendrocyte', 'epithelial cell of lower respiratory tract',
#        'macrophage', 'native cell', 'enteric neuron', 'oligodendrocyte',
#        'cortical cell of adrenal gland', 'fibroblast',
#        'glutamatergic neuron', 'double-positive, alpha-beta thymocyte',
#        'CD8-alpha-alpha-positive, alpha-beta intraepithelial T cell',
#        'thymocyte', 'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'mural cell',
#        'double-positive, alpha-beta thymocyte', 'epithelial cell',
#        'endothelial cell of vascular tree', 'neural progenitor cell',
#        'epithelial cell', 'endocardial cell', 'cardiac muscle cell',
#        'stromal cell', 'cortical cell of adrenal gland', 'stromal cell',
#        'epithelial cell of lower respiratory tract', 'mural cell',
#        'oligodendrocyte', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'GABAergic neuron', 'cardiac muscle cell',
#        'double negative thymocyte', 'stromal cell', 'photoreceptor cell',
#        'GABAergic neuron', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte',
#        'epithelial cell of lower respiratory tract', 'smooth muscle cell',
#        'stromal cell', 'cardiac muscle cell',
#        'central nervous system macrophage',
#        'CD4-positive, alpha-beta T cell', 'epithelial cell',
#        'double-positive, alpha-beta thymocyte', 'granulosa cell',
#        'thymocyte', 'oligodendrocyte', 'double negative thymocyte',
#        'CD8-positive, alpha-beta T cell', 'mesenchymal cell',
#        'oligodendrocyte', 'retinal rod cell',
#        'double-positive, alpha-beta thymocyte',
#        'cerebral cortex GABAergic interneuron',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract',
#        'basal epithelial cell of tracheobronchial tree', 'fibroblast',
#        'mural cell', 'cortical cell of adrenal gland',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'double negative thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'cortical cell of adrenal gland', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'endocardial cell', 'oligodendrocyte', 'glutamatergic neuron',
#        'oligodendrocyte', 'OFF-bipolar cell', 'fibroblast',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'macrophage', 'epithelial cell of lower respiratory tract',
#        'cardiac muscle cell', 'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'cortical cell of adrenal gland', 'epithelial cell',
#        'cardiac muscle cell', 'type B pancreatic cell',
#        'midzonal region hepatocyte', 'midzonal region hepatocyte',
#        'mural cell', 'stromal cell', 'stromal cell',
#        'double-positive, alpha-beta thymocyte', 'retinal bipolar neuron',
#        'Schwann cell', 'thymocyte', 'oligodendrocyte precursor cell',
#        'oligodendrocyte precursor cell', 'glutamatergic neuron',
#        'progenitor cell', 'pancreatic A cell',
#        'cortical cell of adrenal gland', 'mural cell',
#        'CD8-positive, alpha-beta T cell', 'oligodendrocyte',
#        'epithelial cell', 'endocardial cell', 'oligodendrocyte',
#        'glutamatergic neuron', 'mural cell', 'epithelial cell',
#        'cardiac muscle cell', 'double-positive, alpha-beta thymocyte',
#        'stromal cell', 'oligodendrocyte',
#        'epithelial cell of proximal tubule', 'ON-bipolar cell',
#        'cortical cell of adrenal gland', 'stromal cell',
#        'CD8-positive, alpha-beta T cell', 'cardiac muscle cell',
#        'oligodendrocyte', 'cardiac muscle cell', 'oligodendrocyte',
#        'oligodendrocyte', 'double negative thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'double negative thymocyte', 'Schwann cell', 'stromal cell',
#        'glutamatergic neuron', 'OFF-bipolar cell',
#        'double negative thymocyte', 'cardiac muscle cell',
#        'cardiac muscle cell', 'mural cell',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of lower respiratory tract', 'macrophage',
#        'double-positive, alpha-beta thymocyte', 'endocardial cell',
#        'oligodendrocyte', 'erythroid progenitor cell',
#        'double negative thymocyte', 'endocardial cell', 'fibroblast',
#        'enterocyte', 'cardiac muscle cell', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'mural cell',
#        'oligodendrocyte', 'stromal cell', 'ON-bipolar cell',
#        'CD4-positive, alpha-beta T cell', 'stromal cell',
#        'epithelial cell of lower respiratory tract', 'alpha-beta T cell',
#        'ON-bipolar cell', 'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule', 'alpha-beta T cell',
#        'fibroblast', 'cardiac muscle cell', 'mural cell',
#        'epithelial cell', 'stromal cell', 'epithelial cell',
#        'stromal cell', 'stromal cell', 'endocardial cell',
#        'oligodendrocyte', 'cell of skeletal muscle', 'stromal cell',
#        'enteric neuron', 'epithelial cell of lower respiratory tract',
#        'double negative thymocyte', 'glutamatergic neuron',
#        'double negative thymocyte', 'oligodendrocyte', 'oligodendrocyte',
#        'oligodendrocyte', 'glutamatergic neuron', 'endocardial cell',
#        'oligodendrocyte', 'glutamatergic neuron', 'cardiac muscle cell',
#        'oligodendrocyte', 'myeloid cell', 'glutamatergic neuron',
#        'memory B cell', 'oligodendrocyte', 'alpha-beta T cell',
#        'cardiac muscle cell', 'retinal bipolar neuron', 'stromal cell',
#        'absorptive cell', 'stromal cell', 'mural cell', 'oligodendrocyte',
#        'oligodendrocyte', 'double negative thymocyte',
#        'epithelial cell of proximal tubule',
#        'epithelial cell of proximal tubule', 'native cell',
#        'glutamatergic neuron', 'double-positive, alpha-beta thymocyte',
#        'GABAergic neuron', 'fibroblast', 'cardiac muscle cell',
#        'mural cell', 'oligodendrocyte', 'mural cell',
#        'migratory enteric neural crest cell', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte', 'mural cell',
#        'stromal cell', 'oligodendrocyte',
#        'cortical cell of adrenal gland', 'glutamatergic neuron',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of proximal tubule',
#        'CD8-positive, alpha-beta T cell', 'cardiac muscle cell',
#        'thymocyte', 'alpha-beta T cell', 'oligodendrocyte',
#        'oligodendrocyte', 'photoreceptor cell', 'oligodendrocyte',
#        'epithelial cell', 'pancreatic A cell',
#        'double-positive, alpha-beta thymocyte',
#        'cortical cell of adrenal gland', 'cortical cell of adrenal gland',
#        'stromal cell', 'endothelial cell', 'native cell', 'mural cell',
#        'intestinal epithelial cell', 'contractile cell',
#        'endothelial cell of vascular tree', 'cardiac muscle cell',
#        'endocardial cell', 'epithelial cell of proximal tubule',
#        'oligodendrocyte', 'cardiac muscle cell',
#        'epithelial cell of lower respiratory tract', 'macrophage',
#        'oligodendrocyte', 'fibroblast', 'epithelial cell', 'fibroblast',
#        'thymocyte', 'pancreatic epsilon cell',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'cardiac muscle cell', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte', 'alpha-beta T cell',
#        'glutamatergic neuron', 'endothelial cell of lymphatic vessel',
#        'native cell', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'endocardial cell', 'Schwann cell',
#        'cortical cell of adrenal gland', 'oligodendrocyte',
#        'endocrine cell', 'endocrine cell', 'photoreceptor cell',
#        'oligodendrocyte', 'granulosa cell', 'epithelial cell',
#        'oligodendrocyte', 'cortical cell of adrenal gland',
#        'cortical cell of adrenal gland',
#        'cerebral cortex GABAergic interneuron',
#        'cortical cell of adrenal gland', 'retina horizontal cell',
#        'cortical cell of adrenal gland', 'skeletal muscle fibroblast',
#        'endocardial cell', 'neural progenitor cell', 'neuron',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'glutamatergic neuron', 'glutamatergic neuron',
#        'double-positive, alpha-beta thymocyte', 'stromal cell',
#        'oligodendrocyte', 'CD8-positive, alpha-beta T cell',
#        'alternatively activated macrophage',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'endocrine cell', 'glutamatergic neuron', 'mural cell',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'sympathetic neuron', 'Schwann cell', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'T cell', 'endothelial cell of lymphatic vessel',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'cortical cell of adrenal gland', 'thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'intestinal epithelial cell', 'intestinal epithelial cell',
#        'oligodendrocyte', 'oligodendrocyte', 'stromal cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'oligodendrocyte', 'cortical cell of adrenal gland',
#        'glutamatergic neuron', 'retinal bipolar neuron',
#        'oligodendrocyte', 'cardiac muscle cell', 'primordial germ cell',
#        'intestinal epithelial cell', 'oligodendrocyte', 'mural cell',
#        'oligodendrocyte', 'retinal bipolar neuron', 'endocardial cell',
#        'double-positive, alpha-beta thymocyte', 'epithelial cell',
#        'cortical cell of adrenal gland', 'enterocyte', 'fibroblast',
#        'cortical cell of adrenal gland', 'oligodendrocyte', 'mast cell',
#        'oligodendrocyte', 'stromal cell', 'stromal cell', 'fibroblast',
#        'stromal cell', 'cortical cell of adrenal gland',
#        'smooth muscle cell', 'stromal cell', 'cardiac muscle cell',
#        'ON-bipolar cell', 'oligodendrocyte', 'glutamatergic neuron',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'cardiac muscle cell', 'mural cell', 'macrophage',
#        'type II pneumocyte', 'cortical cell of adrenal gland',
#        'oligodendrocyte', 'oligodendrocyte',
#        'CD8-positive, alpha-beta T cell', 'double negative thymocyte',
#        'enterocyte of epithelium of large intestine', 'oligodendrocyte',
#        'cortical cell of adrenal gland', 'oligodendrocyte',
#        'epithelial cell of proximal tubule', 'double negative thymocyte',
#        'stromal cell of ovary', 'retinal pigment epithelial cell',
#        'cardiac muscle cell', 'Mueller cell', 'neural progenitor cell',
#        'epithelial cell', 'retinal rod cell', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'intestinal epithelial cell', 'intestinal epithelial cell',
#        'glutamatergic neuron', 'double-positive, alpha-beta thymocyte',
#        'stromal cell', 'oligodendrocyte', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'lung secretory cell',
#        'dermis microvascular lymphatic vessel endothelial cell',
#        'alpha-beta T cell', 'alpha-beta T cell', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'cortical cell of adrenal gland',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'glutamatergic neuron', 'cardiac muscle cell', 'T cell',
#        'Schwann cell', 'oligodendrocyte', 'chromaffin cell',
#        'type B pancreatic cell', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'stromal cell',
#        'periportal region hepatocyte', 'periportal region hepatocyte',
#        'oligodendrocyte', 'double-positive, alpha-beta thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'double-positive, alpha-beta thymocyte', 'type B pancreatic cell',
#        'thymocyte', 'astrocyte', 'oligodendrocyte', 'oligodendrocyte',
#        'alpha-beta T cell', 'double-positive, alpha-beta thymocyte',
#        'stromal cell', 'cortical cell of adrenal gland',
#        'oligodendrocyte', 'oligodendrocyte', 'epicardial adipocyte',
#        'type B pancreatic cell', 'granulosa cell', 'glutamatergic neuron',
#        'enterocyte', 'stromal cell', 'cardiac muscle cell',
#        'cardiac endothelial cell',
#        'double-positive, alpha-beta thymocyte',
#        'endothelial cell of vascular tree',
#        'endothelial cell of vascular tree', 'oligodendrocyte',
#        'oligodendrocyte', 'oligodendrocyte', 'oligodendrocyte',
#        'cardiac muscle cell', 'oligodendrocyte', 'thymocyte',
#        'mural cell', 'double-positive, alpha-beta thymocyte',
#        'retinal rod cell', 'Sertoli cell', 'neuron',
#        'cerebral cortex GABAergic interneuron',
#        'intestinal epithelial cell', 'oligodendrocyte', 'thymocyte',
#        'oligodendrocyte', 'cardiac muscle cell',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract', 'oligodendrocyte',
#        'thymocyte', 'Sertoli cell', 'oligodendrocyte',
#        'cardiac muscle cell', 'enteric neuron', 'enteric neuron',
#        'oligodendrocyte', 'double negative thymocyte',
#        'epithelial cell of lower respiratory tract', 'native cell',
#        'mural cell', 'oligodendrocyte', 'oligodendrocyte',
#        'endothelial cell of lymphatic vessel', 'myeloid cell',
#        'thymocyte', 'oligodendrocyte', 'stromal cell',
#        'glutamatergic neuron', 'alpha-beta T cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'stromal cell', 'CD4-positive, alpha-beta T cell', 'mural cell',
#        'glutamatergic neuron', 'cardiac muscle cell',
#        'double-positive, alpha-beta thymocyte',
#        'oligodendrocyte precursor cell', 'oligodendrocyte',
#        'stromal cell', 'thymocyte', 'mural cell', 'epithelial cell',
#        'epithelial cell', 'alpha-beta T cell',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'basal cell',
#        'endothelial cell of vascular tree',
#        'cortical cell of adrenal gland',
#        'CD4-positive, alpha-beta T cell', 'mural cell',
#        'cardiac muscle cell', 'enteric neuron', 'enteric neuron',
#        'contractile cell', 'endothelial cell of vascular tree',
#        'endothelial cell of lymphatic vessel',
#        'epithelial cell of proximal tubule', 'myeloid cell',
#        'endocrine cell', 'retinal rod cell', 'cardiac muscle cell',
#        'fibroblast', 'cardiac muscle cell',
#        'cortical cell of adrenal gland', 'oligodendrocyte',
#        'oligodendrocyte', 'oligodendrocyte', 'alpha-beta T cell',
#        'macrophage', 'thymocyte', 'double-positive, alpha-beta thymocyte',
#        'epithelial cell of lower respiratory tract',
#        'double negative thymocyte', 'endocardial cell',
#        'cardiac muscle cell', 'mural cell', 'alpha-beta T cell',
#        'mural cell', 'cardiac muscle cell', 'epithelial cell',
#        'epithelial cell of lung', 'central nervous system macrophage',
#        'oligodendrocyte', 'ON-bipolar cell', 'oligodendrocyte',
#        'alpha-beta T cell',
#        'CD8-alpha-alpha-positive, alpha-beta intraepithelial T cell',
#        'double-positive, alpha-beta thymocyte', 'endocardial cell',
#        'oligodendrocyte', 'mural cell', 'stromal cell', 'stromal cell',
#        'endothelial cell of lymphatic vessel', 'myeloid cell',
#        'alpha-beta T cell', 'glutamatergic neuron',
#        'double negative thymocyte', 'oligodendrocyte', 'oligodendrocyte',
#        'regulatory T cell', 'glutamatergic neuron',
#        'double-positive, alpha-beta thymocyte',
#        'oligodendrocyte precursor cell',
#        'professional antigen presenting cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'alpha-beta T cell', 'contractile cell', 'stromal cell',
#        'stromal cell', 'CD8-positive, alpha-beta T cell',
#        'CD8-positive, alpha-beta T cell', 'oligodendrocyte',
#        'oligodendrocyte', 'glutamatergic neuron',
#        'double-positive, alpha-beta thymocyte', 'glutamatergic neuron',
#        'oligodendrocyte', 'oligodendrocyte', 'native cell',
#        'oligodendrocyte', 'glutamatergic neuron',
#        'retina horizontal cell', 'endothelial cell of vascular tree',
#        'epithelial cell', 'enterocyte of epithelium of large intestine',
#        'oligodendrocyte', 'endothelial cell of lymphatic vessel',
#        'cardiac muscle cell', 'central nervous system macrophage',
#        'epithelial cell', 'double-positive, alpha-beta thymocyte',
#        'native cell', 'oligodendrocyte',
#        'epithelial cell of proximal tubule', 'enterocyte',
#        'epithelial cell of proximal tubule',
#        'cerebral cortex GABAergic interneuron', 'endocrine cell',
#        'oligodendrocyte', 'double-positive, alpha-beta thymocyte',
#        'endothelial cell of lymphatic vessel', 'native cell',
#        'stromal cell', 'intestinal epithelial cell',
#        'cardiac muscle cell', 'oligodendrocyte', 'stromal cell',
#        'fibroblast', 'epithelial cell of lower respiratory tract',
#        'endocardial cell', 'oligodendrocyte', 'epithelial cell',
#        'cortical cell of adrenal gland', 'myeloid cell', 'mast cell',
#        'stromal cell', 'stromal cell', 'glutamatergic neuron',
#        'oligodendrocyte', 'glutamatergic neuron', 'glutamatergic neuron',
#        'double-positive, alpha-beta thymocyte', 'epithelial cell',
#        'cortical cell of adrenal gland', 'stromal cell', 'stromal cell',
#        'epithelial cell of lower respiratory tract',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'oligodendrocyte', 'thymocyte',
#        'double-positive, alpha-beta thymocyte', 'glial cell',
#        'double-positive, alpha-beta thymocyte', 'oligodendrocyte',
#        'oligodendrocyte', 'glutamatergic neuron', 'acinar cell',
#        'glutamatergic neuron', 'oligodendrocyte', 'oligodendrocyte',
#        'kidney loop of Henle thick ascending limb epithelial cell',
#        'glial cell', 'stromal cell', 'stromal cell',
#        'double negative thymocyte', 'oligodendrocyte',
#        'epithelial cell of lower respiratory tract', 'oligodendrocyte',
#        'native cell', 'mural cell',
#        'endothelial cell of lymphatic vessel',
#        'endothelial cell of lymphatic vessel',
#        'cortical cell of adrenal gland', 'stromal cell',
#        'oligodendrocyte', 'endothelial cell of vascular tree',
#        'endothelial cell of vascular tree',
#        'central nervous system macrophage', 'type B pancreatic cell',
#        'cardiac muscle cell', 'Mueller cell', 'fibroblast',
#        'central nervous system macrophage', 'oligodendrocyte',
#        'pancreatic A cell', 'CD8-positive, alpha-beta T cell',
#        'GABAergic neuron', 'epithelial cell of proximal tubule',
#        'oligodendrocyte', 'cortical cell of adrenal gland',
#        'GABAergic neuron', 'cortical cell of adrenal gland', 'thymocyte',
#        'oligodendrocyte', 'type II pneumocyte', 'fibroblast',
#        'endocardial cell', 'stromal cell', 'epithelial cell',
#        'GABAergic neuron', 'stromal cell', 'oligodendrocyte',
#        'cardiac muscle cell', 'mesenchymal cell',
#        'double-positive, alpha-beta thymocyte', 'mural cell',
#        'double-positive, alpha-beta thymocyte', 'fibroblast',
#        'double-positive, alpha-beta thymocyte',
#        'cortical cell of adrenal gland', 'mural cell',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte', 'retinal bipolar neuron',
#        'cardiac muscle cell', 'oligodendrocyte', 'oligodendrocyte',
#        'cardiac muscle cell', 'thymocyte',
#        'double-positive, alpha-beta thymocyte', 'type B pancreatic cell',
#        'oligodendrocyte', 'oligodendrocyte', 'alpha-beta T cell',
#        'myeloid cell', 'basal cell', 'granulosa cell', 'stromal cell',
#        'mural cell', 'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract',
#        'epithelial cell of lower respiratory tract', 'stromal cell',
#        'stromal cell', 'thymocyte', 'stromal cell', 'mural cell',
#        'glutamatergic neuron', 'cardiac muscle cell',
#        'cardiac muscle cell', 'cerebral cortex GABAergic interneuron',
#        'cortical cell of adrenal gland',
#        'double-positive, alpha-beta thymocyte',
#        'double-positive, alpha-beta thymocyte',
#        'central nervous system macrophage', 'alpha-beta T cell',
#        'photoreceptor cell', 'GABAergic neuron', 'mural cell',
#        'oligodendrocyte', 'cerebral cortex GABAergic interneuron',
#        'epicardial adipocyte', 'microglial cell',
#        'endothelial cell of vascular tree',
#        'central nervous system macrophage', 'cardiac muscle cell',
#        'enterocyte', 'oligodendrocyte',
#        'double-positive, alpha-beta thymocyte', 'cardiac muscle cell',
#        'cardiac muscle cell', 'epithelial cell', 'GABAergic neuron',
#        'alpha-beta T cell', 'oligodendrocyte', 'cardiac muscle cell',
#        'glutamatergic neuron', 'CD8-positive, alpha-beta T cell',
#        'oligodendrocyte', 'double-positive, alpha-beta thymocyte',
#        'GABAergic neuron', 'stromal cell'], dtype='<U84')
