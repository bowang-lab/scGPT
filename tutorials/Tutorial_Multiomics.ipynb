# %% [markdown]
# # Fine-tuning on Pre-trained Model for Multiomic Integration
# In this tutorial, we demonstrate how to fine-tune a pre-trained model for multiomic integration. We use the BMMC dataset as an example for RNA and protein abundance data integration from CITE-seq. The BMMC dataset consists of multiple batches by donor origin. In the paired integration setting, each cell contains both RNA and protein measurements. We fine-tune on the pre-trained whole-body model.
#
# We summarize the fine-tuning pipeline in the following steps, which can be used as a general recipe for finetuning on integration tasks and beyond:
#
#      1. Specify hyper-parameter setup for integration task
#
#      2. Load and pre-process data
#
#      3. Load the pre-trained scGPT model
#
#      4. Finetune scGPT with task-specific objectives
#
#      5. Evaluate fine-tuned scGPT

# %%
import copy
import gc
import json
import os
from pathlib import Path
import sys
import time
import traceback
#from typing import List, Tuple, Dict, Union, Optional
import warnings

import torch
from anndata import AnnData
import scanpy as sc
import scvi
import numpy as np
import wandb
from scipy.sparse import issparse
import matplotlib.pyplot as plt
from torch import nn
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from torchtext.vocab import Vocab
from torchtext._torchtext import (
    Vocab as VocabPybind,
)
import pandas as pd
import scipy.sparse as sp
from sklearn import preprocessing

sys.path.insert(0, "../")
from scgpt import prepare_data, prepare_dataloader, define_wandb_metrcis, evaluate, eval_testdata, train
from scgpt.tokenizer import tokenize_and_pad_batch
from scgpt.model import MultiOmicTransformerModel

import scgpt as scg
from scgpt.tokenizer.gene_tokenizer import GeneVocab
from scgpt.tokenizer import random_mask_value
from scgpt.loss import (
    masked_mse_loss,
    masked_relative_error,
    criterion_neg_log_bernoulli,
)
from scgpt.preprocess import Preprocessor
from scgpt.utils import set_seed, category_str2int, eval_scib_metrics

sc.set_figure_params(figsize=(4, 4))
os.environ["KMP_WARNINGS"] = "off"
warnings.filterwarnings('ignore')
# Out:
# Global seed set to 0
# /ssd003/home/chloexq/.cache/pypoetry/virtualenvs/scgpt--qSLVbd1-py3.9/lib/python3.9/site-packages/scanpy/_settings.py:450: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`
#   IPython.display.set_matplotlib_formats(*ipython_format)

# %% [markdown]
# ## Step1: Specify hyper-parameter setup for integration task
# Here we provide some hyper-parameter recommendations for the multiomic integration task. Note that the BMMC dataset contains multiple batches to be integrated. Therefore, in addition to the default gene modelling objectives, we also turn on DAR objectives specifically to faciliate batch integration. We also turn on the use_mod argument as default to ensure that the model is modality-aware during training.

# %%
hyperparameter_defaults = dict(
    task = 'multiomic',
    seed=42,
    dataset_name="BMMC", # Dataset name
    do_train=True, # Flag to indicate whether to do update model parameters during training
    load_model="../save/scGPT_human", # Path to pre-trained model
    freeze = False, #freeze
    GEP=True, # Gene expression modelling
    GEPC=True, # Gene expression modelling for cell objective
    CLS=False,
    ESC=False,
    DAR = True, # DAR objective weight for batch correction
    DSBN = False,  # Domain-spec batchnorm,
    mask_ratio=0.4, # Default mask ratio
    explicit_zero_prob = False,  # whether explicit bernoulli for zeros
    ecs_thres=0,  # Elastic cell similarity objective, 0.0 to 1.0, 0.0 to disable
    dab_weight=1.0,
    use_batch_labels = True,
    use_mod = True,
    per_seq_batch_sample = False,
    epochs=25, # Default number of epochs for fine-tuning
    input_layer_key = "X_binned", # Default expression value binning in data pre-processing
    n_bins=51, # Default number of bins for value binning in data pre-processing
    n_hvg = 1200,  # Default number of highly variable genes
    n_hvp = 4000,
    max_seq_len = 4001, # # Default n_hvg+1
    lr=1e-3, # Default learning rate for fine-tuning
    batch_size=16, # Default batch size for fine-tuning
    layer_size=512,
    nlayers=4,
    nhead=8, # if load model, batch_size, layer_size, nlayers, nhead will be ignored
    dropout=0.2, # Default dropout rate during model fine-tuning
    schedule_ratio=0.95,  # Default rate for learning rate decay
    save_eval_interval=5, # Default model evaluation interval
    log_interval=100, # Default log interval
    fast_transformer=True, # Default setting
    pre_norm=False, # Default setting
    amp=True,  # Default setting: Automatic Mixed Precision
    pad_token = "<pad>",
    mask_value = -1,
    pad_value = -2,
    include_zero_gene = False,
)

# %%
run = wandb.init(
    config=hyperparameter_defaults,
    project="scGPT",
    reinit=True,
    settings=wandb.Settings(start_method="fork"),
)
config = wandb.config
print(config)

set_seed(config.seed)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: chloewxq (scformer). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/fs01/home/chloexq/scGPT/tutorials/wandb/run-20231019_144009-g5f0ui2j</code>
# Syncing run <strong><a href='https://wandb.ai/scformer/scGPT/runs/g5f0ui2j' target="_blank">frosty-bush-454</a></strong> to <a href='https://wandb.ai/scformer/scGPT' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/scformer/scGPT' target="_blank">https://wandb.ai/scformer/scGPT</a>
#  View run at <a href='https://wandb.ai/scformer/scGPT/runs/g5f0ui2j' target="_blank">https://wandb.ai/scformer/scGPT/runs/g5f0ui2j</a>
# {'task': 'multiomic', 'seed': 42, 'dataset_name': 'BMMC', 'do_train': True, 'load_model': '../save/scGPT_human', 'freeze': False, 'GEP': True, 'GEPC': True, 'CLS': False, 'ESC': False, 'DAR': True, 'DSBN': False, 'mask_ratio': 0.4, 'explicit_zero_prob': False, 'ecs_thres': 0, 'dab_weight': 1.0, 'use_batch_labels': True, 'use_mod': True, 'per_seq_batch_sample': False, 'epochs': 25, 'input_layer_key': 'X_binned', 'n_bins': 51, 'n_hvg': 1200, 'n_hvp': 4000, 'max_seq_len': 4001, 'lr': 0.001, 'batch_size': 16, 'layer_size': 512, 'nlayers': 4, 'nhead': 8, 'dropout': 0.2, 'schedule_ratio': 0.95, 'save_eval_interval': 5, 'log_interval': 100, 'fast_transformer': True, 'pre_norm': False, 'amp': True, 'pad_token': '<pad>', 'mask_value': -1, 'pad_value': -2, 'include_zero_gene': False}

# %%
# settings for input and preprocessing
special_tokens = [config.pad_token, "<cls>", "<eoc>"]

# %%
dataset_name = config.dataset_name
save_dir = Path(f"./save/dev_{dataset_name}-{time.strftime('%b%d-%H-%M')}/")
save_dir.mkdir(parents=True, exist_ok=True)
print(f"save to {save_dir}")
logger = scg.logger
scg.utils.add_file_handler(logger, save_dir / "run.log")
# Out:
# save to save/dev_BMMC-Oct19-14-40

# %% [markdown]
# ## Step 2: Load and pre-process data

# %% [markdown]
# ### 2.1 Load the BMMC data
# Please download the data from https://drive.google.com/file/d/10RxboePS5p2Jj2Sfq1Ghzgqnl6nqPv5V/view?usp=sharing
#
# For the purpose of this tutorial, we selected a 12K+ cell subset from the BMMC dataset (originally 90K+ cells) to speed up training. More specifically, we filtered on the first 3 donors (batches) with B, Mono and T cell subtypes as shown in the data loading step below.

# %%
if dataset_name == 'BMMC':
    adata = sc.read('BMMC_processed.h5ad')
    # subset to first 3 donors with B, Mono and T cell subtypes
    adata = adata[adata.obs.DonorID.isin([10886, 11466, 12710]) & adata.obs.cell_type.isin(np.unique(adata.obs.cell_type.values)[:17])]
    adata.obs["celltype"] = adata.obs["cell_type"].astype(str).astype('category')
    adata.var["gene_name"] = adata.var.index.tolist()
    le = preprocessing.LabelEncoder()
    encoded_batch = le.fit_transform(adata.obs['batch'].values)
    adata.obs["batch_id"] =  encoded_batch
    adata.obs["str_batch"] = adata.obs["batch_id"].astype('category')
    adata_protein = adata[:, adata.var.feature_types.isin(['ADT'])].copy()
    adata_protein.var.index = ['p_' + i for i in adata_protein.var.index]
    adata = adata[:, adata.var.feature_types.isin(['GEX'])].copy()
    data_is_raw = False

# %%
if config.use_mod:
    gene_rna_df = pd.DataFrame(index = adata.var.index.tolist())
    gene_rna_df['mod'] = 'RNA'
    gene_protein_df = pd.DataFrame(index = adata_protein.var.index.tolist())
    gene_protein_df['mod'] = 'Protein'
    gene_loc_df = pd.concat([gene_rna_df, gene_protein_df])
    gene_loc_df['mod'] = gene_loc_df['mod'].astype('category')

# %% [markdown]
# ### 2.2 Cross-check gene set with the pre-trained model
# Note that we retain the common gene set between the data and the pre-trained model for further fine-tuning.

# %%
if config.load_model is not None:
    model_dir = Path(config.load_model)
    model_config_file = model_dir / "args.json"
    model_file = model_dir / "best_model.pt"
    vocab_file = model_dir / "vocab.json"

    vocab = GeneVocab.from_file(vocab_file)
    for s in special_tokens:
        if s not in vocab:
            vocab.append_token(s)

    adata.var["id_in_vocab"] = [
        1 if gene in vocab else -1 for gene in adata.var["gene_name"]
    ]
    gene_ids_in_vocab = np.array(adata.var["id_in_vocab"])
    logger.info(
        f"match {np.sum(gene_ids_in_vocab >= 0)}/{len(gene_ids_in_vocab)} genes "
        f"in vocabulary of size {len(vocab)}."
    )
    old_vocab = vocab
embsize = config.layer_size
nhead = config.nhead
nlayers = config.nlayers
d_hid = config.layer_size
# Out:
# scGPT - INFO - match 12587/13953 genes in vocabulary of size 60697.

# %% [markdown]
# ### 2.3 Pre-process the data
# We follow the standardized pipline of depth normalization, log normalization, and highly vairable gene (HVG) selection for data pre-processing. We further introduce value binning to obtain the relative expressions of each HVG. Given multiple sequencing modalities, we perform the pre-processing steps on each individual modality first, and then combine them into multi-modal sequences as model input.

# %% [markdown]
# #### 2.3.1 Pre-process the RNA data

# %%
preprocessor = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=1,  # step 1
    filter_cell_by_counts=1,  # step 2
    normalize_total=1e4,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=data_is_raw,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=config.n_hvg,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor="seurat_v3" if data_is_raw else "cell_ranger",
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor(adata, batch_key=None)
# Out:
# scGPT - INFO - Filtering genes by counts ...
# scGPT - INFO - Filtering cells by counts ...
# scGPT - INFO - Normalizing total counts ...
# scGPT - INFO - Subsetting highly variable genes ...
# scGPT - WARNING - No batch_key is provided, will use all cells for HVG selection.
# scGPT - INFO - Binning data ...

# %% [markdown]
# #### 2.3.2 Pre-process the Protein data

# %%
preprocessor_protein = Preprocessor(
    use_key="X",  # the key in adata.layers to use as raw data
    filter_gene_by_counts=0,  # step 1
    filter_cell_by_counts=False,  # step 2
    normalize_total=False,  # 3. whether to normalize the raw data and to what sum
    result_normed_key="X_normed",  # the key in adata.layers to store the normalized data
    log1p=False,  # 4. whether to log1p the normalized data
    result_log1p_key="X_log1p",
    subset_hvg=False,  # 5. whether to subset the raw data to highly variable genes
    hvg_flavor=None,
    binning=config.n_bins,  # 6. whether to bin the raw data and to what number of bins
    result_binned_key="X_binned",  # the key in adata.layers to store the binned data
)
preprocessor_protein(adata_protein, batch_key=None)
# Out:
# scGPT - INFO - Filtering cells by counts ...
# scGPT - INFO - Binning data ...

# %% [markdown]
# #### 2.3.3 Combine RNA, and Protein data

# %%
data_combined = np.concatenate([adata.layers["X_binned"], adata_protein.layers["X_binned"]], axis=1)
adata = AnnData(
    X=data_combined,
    obs=adata.obs,
    var=pd.DataFrame(index=adata.var_names.tolist() + adata_protein.var_names.tolist()),
    layers={"X_binned": data_combined,}
)
adata.var["gene_name"] = adata.var.index.tolist()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 12578 × 1334
#     obs: 'GEX_n_genes_by_counts', 'GEX_pct_counts_mt', 'GEX_size_factors', 'GEX_phase', 'ADT_n_antibodies_by_counts', 'ADT_total_counts', 'ADT_iso_count', 'cell_type', 'batch', 'ADT_pseudotime_order', 'GEX_pseudotime_order', 'Samplename', 'Site', 'DonorNumber', 'Modality', 'VendorLot', 'DonorID', 'DonorAge', 'DonorBMI', 'DonorBloodType', 'DonorRace', 'Ethnicity', 'DonorGender', 'QCMeds', 'DonorSmoker', 'is_train', 'celltype', 'batch_id', 'str_batch', 'n_counts'
#     var: 'gene_name'
#     layers: 'X_binned'

# %%
if config.per_seq_batch_sample:
    # sort the adata by batch_id in advance
    adata_sorted = adata[adata.obs["batch_id"].argsort()].copy()

# %% [markdown]
# ### 2.4 Tokenize the input data for model fine-tuning

# %%
all_counts = (
    adata.layers[config.input_layer_key].A
    if issparse(adata.layers[config.input_layer_key])
    else adata.layers[config.input_layer_key]
)
genes = adata.var["gene_name"].tolist()

celltypes_labels = adata.obs["celltype"].tolist()  # make sure count from 0
num_types = len(set(celltypes_labels))
celltypes_labels = np.array(celltypes_labels)

batch_ids = adata.obs["batch_id"].tolist()
num_batch_types = len(set(batch_ids))
batch_ids = np.array(batch_ids)

# %%
if config.use_mod:
    mod_type = np.array([gene_loc_df.loc[g, 'mod'] for g in genes])
    vocab_mod = Vocab(VocabPybind(np.unique(gene_loc_df['mod']).tolist() + special_tokens, None))
    vocab_mod.set_default_index(vocab_mod["<pad>"])
    mod_type = np.array(vocab_mod(list(mod_type)), dtype=int)
    ntokens_mod = len(vocab_mod)

# %%
(
    train_data,
    valid_data,
    train_celltype_labels,
    valid_celltype_labels,
    train_batch_labels,
    valid_batch_labels,
) = train_test_split(
    all_counts, celltypes_labels, batch_ids, test_size=0.1, shuffle=True
)

# %%
num_of_non_zero_genes = [
    np.count_nonzero(train_data[i]) for i in range(train_data.shape[0])
]
print(f"max num of non_zero genes: {np.max(num_of_non_zero_genes)}")
print(f"min num of non_zero genes: {np.min(num_of_non_zero_genes)}")
print(f"average num of non_zero genes: {np.mean(num_of_non_zero_genes)}")
print(
    f"99% quantile num of non_zero genes: {np.quantile(num_of_non_zero_genes, 0.99)}"
)
print(f"max original values: {np.max(train_data)}")
print(
    f"average original non_zero values: {np.mean(train_data[np.nonzero(train_data)])}"
)
print(
    f"99% quantile original non_zero values: {np.quantile(train_data[np.nonzero(train_data)], 0.99)}"
)
print(f"num of celltypes: {num_types}")
# Out:
# max num of non_zero genes: 687
# min num of non_zero genes: 206
# average num of non_zero genes: 341.5295053003534
# 99% quantile num of non_zero genes: 510.0
# max original values: 50
# average original non_zero values: 25.3482856428962
# 99% quantile original non_zero values: 49.0
# num of celltypes: 17

# %%
if config.load_model is None:
    vocab = Vocab(VocabPybind(genes + special_tokens, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)
else:
    pretrained_genes = [g for g in genes + special_tokens if g in old_vocab]
    new_genes = [g for g in genes + special_tokens if g not in old_vocab]
    gene_ids_pretrained = np.array(old_vocab(pretrained_genes), dtype=int)
    # https://discuss.pytorch.org/t/expand-an-existing-embedding-and-linear-layer-nan-loss-value/55670/2
    # Retrieve pretrained weights
    vocab = Vocab(VocabPybind(pretrained_genes + new_genes, None))
    vocab.set_default_index(vocab["<pad>"])
    gene_ids = np.array(vocab(genes), dtype=int)

# %%
tokenized_train = tokenize_and_pad_batch(
    train_data,
    gene_ids,
    max_len=config.max_seq_len,
    vocab=vocab,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    append_cls=True,  # append <cls> token at the beginning
    include_zero_gene=config.include_zero_gene,
    mod_type=mod_type if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)
tokenized_valid = tokenize_and_pad_batch(
    valid_data,
    gene_ids,
    max_len=config.max_seq_len,
    vocab=vocab,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    append_cls=True,
    include_zero_gene=config.include_zero_gene,
    mod_type=mod_type if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)
logger.info(
    f"train set number of samples: {tokenized_train['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_train['genes'].shape[1]}"
)
logger.info(
    f"valid set number of samples: {tokenized_valid['genes'].shape[0]}, "
    f"\n\t feature length: {tokenized_valid['genes'].shape[1]}"
)
# Out:
# scGPT - INFO - train set number of samples: 11320,
# 	 feature length: 688
# scGPT - INFO - valid set number of samples: 1258,
# 	 feature length: 663

# %% [markdown]
# ## Step 3: Load the pre-trained scGPT model
# Note that for multiomic integration, since the pre-trained model does not include the ATAC and protein tokens, we expand the embedding layer by adding these new tokens. We inherit only the gene embedding layer from the pre-trained model, and train rest of the model from scratch.

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dict = torch.load(model_file)
ntokens = len(vocab)  # size of vocabulary
model = MultiOmicTransformerModel(
    ntokens,
    embsize,
    nhead,
    d_hid, 
    nlayers,
    vocab=vocab,
    dropout=config.dropout,
    pad_token=config.pad_token,
    pad_value=config.pad_value,
    do_mvc=config.GEPC,
    do_dab=config.DAR,
    use_batch_labels=config.use_batch_labels,
    num_batch_labels=num_batch_types,
    domain_spec_batchnorm=config.DSBN,
    n_input_bins=config.n_bins,
    ecs_threshold=config.ecs_thres,
    explicit_zero_prob=config.explicit_zero_prob,
    use_fast_transformer=config.fast_transformer,
    pre_norm=config.pre_norm,
    use_mod=config.use_mod,
    ntokens_mod=ntokens_mod if config.use_mod else None,
    vocab_mod=vocab_mod if config.use_mod else None,
)

with torch.no_grad():
    pretrained_emb_weights = model_dict['encoder.embedding.weight'][gene_ids_pretrained, :]
    model.encoder.embedding.weight.data[:len(pretrained_genes), :] = pretrained_emb_weights
    model.encoder.enc_norm.weight.data = model_dict['encoder.enc_norm.weight']
ntokens = len(vocab)

model.to(device)
wandb.watch(model)
print(model)
# Out:
# Using simple batchnorm instead of domain specific batchnorm
# TransformerModel(
#   (encoder): GeneEncoder(
#     (embedding): Embedding(1337, 512, padding_idx=1089)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (value_encoder): ContinuousValueEncoder(
#     (dropout): Dropout(p=0.2, inplace=False)
#     (linear1): Linear(in_features=1, out_features=512, bias=True)
#     (activation): ReLU()
#     (linear2): Linear(in_features=512, out_features=512, bias=True)
#     (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (batch_encoder): BatchLabelEncoder(
#     (embedding): Embedding(3, 512)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (mod_encoder): BatchLabelEncoder(
#     (embedding): Embedding(5, 512, padding_idx=2)
#     (enc_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (bn): BatchNorm1d(512, eps=6.1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (1): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (2): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#       (3): FlashTransformerEncoderLayer(
#         (self_attn): FlashMHA(
#           (Wqkv): Linear(in_features=512, out_features=1536, bias=True)
#           (inner_attn): FlashAttention()
#           (out_proj): Linear(in_features=512, out_features=512, bias=True)
#         )
#         (linear1): Linear(in_features=512, out_features=512, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#         (linear2): Linear(in_features=512, out_features=512, bias=True)
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.2, inplace=False)
#         (dropout2): Dropout(p=0.2, inplace=False)
#       )
#     )
#   )
#   (decoder): ExprDecoder(
#     (fc): Sequential(
#       (0): Linear(in_features=1024, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): Linear(in_features=512, out_features=512, bias=True)
#       (3): LeakyReLU(negative_slope=0.01)
#       (4): Linear(in_features=512, out_features=1, bias=True)
#     )
#   )
#   (cls_decoder): ClsDecoder(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): ReLU()
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): ReLU()
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=1, bias=True)
#   )
#   (mvc_decoder): MVCDecoder(
#     (gene2query): Linear(in_features=1024, out_features=1024, bias=True)
#     (query_activation): Sigmoid()
#     (W): Linear(in_features=1024, out_features=1024, bias=False)
#   )
#   (grad_reverse_discriminator): AdversarialDiscriminator(
#     (_decoder): ModuleList(
#       (0): Linear(in_features=512, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.01)
#       (2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (3): Linear(in_features=512, out_features=512, bias=True)
#       (4): LeakyReLU(negative_slope=0.01)
#       (5): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (out_layer): Linear(in_features=512, out_features=3, bias=True)
#   )
#   (sim): Similarity(
#     (cos): CosineSimilarity()
#   )
#   (creterion_cce): CrossEntropyLoss()
# )

# %%
if config.GEP and config.GEPC:
    criterion_gep_gepc = masked_mse_loss
if config.CLS:
    criterion_cls = nn.CrossEntropyLoss()
if config.DAR:
    criterion_dab = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(
    model.parameters(), lr=config.lr, eps=1e-4 if config.amp else 1e-8
)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1, gamma=config.schedule_ratio)
scaler = torch.cuda.amp.GradScaler(enabled=config.amp)

# %% [markdown]
# ## Step 4: Finetune scGPT with task-specific objectives

# %%
best_val_loss = float("inf")
best_avg_bio = 0.0
best_model = None
define_wandb_metrcis()

for epoch in range(1, config.epochs + 1):
    epoch_start_time = time.time()
    train_data_pt, valid_data_pt = prepare_data(
        tokenized_train=tokenized_train, 
        tokenized_valid=tokenized_valid, 
        train_batch_labels=train_batch_labels,
        valid_batch_labels=valid_batch_labels,
        config=config,
        epoch=epoch,
        sort_seq_batch=config.per_seq_batch_sample)
    
    train_loader = prepare_dataloader(
        train_data_pt,
        batch_size=config.batch_size,
        shuffle=True,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config.per_seq_batch_sample
    )
    valid_loader = prepare_dataloader(
        valid_data_pt,
        batch_size=config.batch_size,
        shuffle=False,
        intra_domain_shuffle=False,
        drop_last=False,
        per_seq_batch_sample=config.per_seq_batch_sample
    )

    if config.do_train:
        train(
            model=model,
            loader=train_loader,
            vocab=vocab,
            criterion_gep_gepc=criterion_gep_gepc if config.GEP and config.GEPC else None,
            criterion_dab=criterion_dab if config.DAR else None,
            criterion_cls=criterion_cls if config.CLS else None,
            scaler=scaler,
            optimizer=optimizer,
            scheduler=scheduler,
            device=device,
            config=config,
            logger=logger,
            epoch=epoch,
        )
    val_loss = evaluate(
        model=model,
        loader=valid_loader,
        vocab=vocab,
        criterion_gep_gepc=criterion_gep_gepc if config.GEP and config.GEPC else None,
        criterion_dab=criterion_dab if config.DAR else None,
        criterion_cls=criterion_cls if config.CLS else None,
        device=device,
        config=config,
        epoch=epoch
    )
    elapsed = time.time() - epoch_start_time
    logger.info("-" * 89)
    logger.info(
        f"| end of epoch {epoch:3d} | time: {elapsed:5.2f}s | "
        f"valid loss {val_loss:5.4f} | "
    )
    logger.info("-" * 89)

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_model = copy.deepcopy(model)
        best_model_epoch = epoch
        logger.info(f"Best model with score {best_val_loss:5.4f}")

    if epoch % config.save_eval_interval == 0 or epoch == config.epochs:
        logger.info(f"Saving model to {save_dir}")
        torch.save(best_model.state_dict(), save_dir / f"model_e{best_model_epoch}.pt")

        # eval on testdata
        results = eval_testdata(
            model = best_model,
            adata_t = adata_sorted if config.per_seq_batch_sample else adata,
            gene_ids = gene_ids,
            vocab = vocab,
            config = config,
            logger = logger,
            include_types=["cls"],
        )
        results["batch_umap"].savefig(
            save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png", dpi=300
        )

        results["celltype_umap"].savefig(
            save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png", dpi=300
        )
        metrics_to_log = {"test/" + k: v for k, v in results.items()}
        metrics_to_log["test/batch_umap"] = wandb.Image(
            str(save_dir / f"embeddings_batch_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )

        metrics_to_log["test/celltype_umap"] = wandb.Image(
            str(save_dir / f"embeddings_celltype_umap[cls]_e{best_model_epoch}.png"),
            caption=f"celltype avg_bio epoch {best_model_epoch}",
        )
        metrics_to_log["test/best_model_epoch"] = best_model_epoch
        wandb.log(metrics_to_log)
        wandb.log({"avg_bio": results.get("avg_bio", 0.0)})

    scheduler.step()
# Out:
# random masking at epoch   1, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   1 | 100/708 batches | lr 0.00100 | ms/batch 68.39 | loss 7695.31 | gep 380.20 |gepc 7314.00 |dar  1.11 |
# scGPT - INFO - | epoch   1 | 200/708 batches | lr 0.00100 | ms/batch 46.00 | loss 242.67 | gep 163.71 |gepc 77.97 |dar  1.00 |
# scGPT - INFO - | epoch   1 | 300/708 batches | lr 0.00100 | ms/batch 46.34 | loss 144.25 | gep 73.30 |gepc 70.11 |dar  0.83 |
# scGPT - INFO - | epoch   1 | 400/708 batches | lr 0.00100 | ms/batch 46.23 | loss 125.95 | gep 63.33 |gepc 61.88 |dar  0.74 |
# scGPT - INFO - | epoch   1 | 500/708 batches | lr 0.00100 | ms/batch 46.02 | loss 123.15 | gep 62.42 |gepc 59.90 |dar  0.83 |
# scGPT - INFO - | epoch   1 | 600/708 batches | lr 0.00100 | ms/batch 46.72 | loss 123.12 | gep 61.53 |gepc 60.91 |dar  0.67 |
# scGPT - INFO - | epoch   1 | 700/708 batches | lr 0.00100 | ms/batch 46.08 | loss 118.63 | gep 58.42 |gepc 59.49 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   1 | time: 36.81s | valid loss 57.1919 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 57.1919
# random masking at epoch   2, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   2 | 100/708 batches | lr 0.00095 | ms/batch 52.34 | loss 118.76 | gep 58.58 |gepc 59.47 |dar  0.71 |
# scGPT - INFO - | epoch   2 | 200/708 batches | lr 0.00095 | ms/batch 46.62 | loss 116.45 | gep 57.26 |gepc 58.47 |dar  0.72 |
# scGPT - INFO - | epoch   2 | 300/708 batches | lr 0.00095 | ms/batch 46.74 | loss 115.72 | gep 57.05 |gepc 57.97 |dar  0.70 |
# scGPT - INFO - | epoch   2 | 400/708 batches | lr 0.00095 | ms/batch 46.27 | loss 113.91 | gep 56.33 |gepc 56.89 |dar  0.68 |
# scGPT - INFO - | epoch   2 | 500/708 batches | lr 0.00095 | ms/batch 45.93 | loss 113.27 | gep 55.73 |gepc 56.82 |dar  0.72 |
# scGPT - INFO - | epoch   2 | 600/708 batches | lr 0.00095 | ms/batch 45.97 | loss 111.45 | gep 54.83 |gepc 55.92 |dar  0.70 |
# scGPT - INFO - | epoch   2 | 700/708 batches | lr 0.00095 | ms/batch 45.99 | loss 111.84 | gep 55.05 |gepc 56.07 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   2 | time: 34.99s | valid loss 55.5510 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 55.5510
# random masking at epoch   3, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   3 | 100/708 batches | lr 0.00090 | ms/batch 46.50 | loss 112.09 | gep 55.07 |gepc 56.32 |dar  0.71 |
# scGPT - INFO - | epoch   3 | 200/708 batches | lr 0.00090 | ms/batch 46.05 | loss 108.88 | gep 53.38 |gepc 54.78 |dar  0.71 |
# scGPT - INFO - | epoch   3 | 300/708 batches | lr 0.00090 | ms/batch 46.11 | loss 109.68 | gep 53.93 |gepc 55.09 |dar  0.66 |
# scGPT - INFO - | epoch   3 | 400/708 batches | lr 0.00090 | ms/batch 46.23 | loss 108.77 | gep 53.34 |gepc 54.76 |dar  0.68 |
# scGPT - INFO - | epoch   3 | 500/708 batches | lr 0.00090 | ms/batch 46.14 | loss 109.98 | gep 54.16 |gepc 55.13 |dar  0.69 |
# scGPT - INFO - | epoch   3 | 600/708 batches | lr 0.00090 | ms/batch 46.82 | loss 110.03 | gep 54.07 |gepc 55.23 |dar  0.73 |
# scGPT - INFO - | epoch   3 | 700/708 batches | lr 0.00090 | ms/batch 45.92 | loss 110.50 | gep 54.46 |gepc 55.30 |dar  0.74 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   3 | time: 34.38s | valid loss 55.1387 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 55.1387
# random masking at epoch   4, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   4 | 100/708 batches | lr 0.00086 | ms/batch 64.29 | loss 108.20 | gep 53.18 |gepc 54.32 |dar  0.71 |
# scGPT - INFO - | epoch   4 | 200/708 batches | lr 0.00086 | ms/batch 64.46 | loss 108.02 | gep 53.07 |gepc 54.25 |dar  0.70 |
# scGPT - INFO - | epoch   4 | 300/708 batches | lr 0.00086 | ms/batch 61.71 | loss 107.58 | gep 52.96 |gepc 53.92 |dar  0.70 |
# scGPT - INFO - | epoch   4 | 400/708 batches | lr 0.00086 | ms/batch 50.92 | loss 105.60 | gep 51.80 |gepc 53.14 |dar  0.65 |
# scGPT - INFO - | epoch   4 | 500/708 batches | lr 0.00086 | ms/batch 46.14 | loss 108.32 | gep 53.05 |gepc 54.54 |dar  0.74 |
# scGPT - INFO - | epoch   4 | 600/708 batches | lr 0.00086 | ms/batch 47.72 | loss 108.86 | gep 53.42 |gepc 54.74 |dar  0.70 |
# scGPT - INFO - | epoch   4 | 700/708 batches | lr 0.00086 | ms/batch 46.15 | loss 107.06 | gep 52.54 |gepc 53.81 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   4 | time: 40.14s | valid loss 51.8802 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.8802
# random masking at epoch   5, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   5 | 100/708 batches | lr 0.00081 | ms/batch 46.85 | loss 108.80 | gep 53.28 |gepc 54.76 |dar  0.75 |
# scGPT - INFO - | epoch   5 | 200/708 batches | lr 0.00081 | ms/batch 46.90 | loss 104.90 | gep 51.64 |gepc 52.58 |dar  0.68 |
# scGPT - INFO - | epoch   5 | 300/708 batches | lr 0.00081 | ms/batch 46.03 | loss 106.43 | gep 52.42 |gepc 53.36 |dar  0.65 |
# scGPT - INFO - | epoch   5 | 400/708 batches | lr 0.00081 | ms/batch 46.02 | loss 105.34 | gep 51.62 |gepc 53.01 |dar  0.71 |
# scGPT - INFO - | epoch   5 | 500/708 batches | lr 0.00081 | ms/batch 46.52 | loss 106.13 | gep 52.03 |gepc 53.37 |dar  0.73 |
# scGPT - INFO - | epoch   5 | 600/708 batches | lr 0.00081 | ms/batch 46.30 | loss 105.66 | gep 51.81 |gepc 53.20 |dar  0.65 |
# scGPT - INFO - | epoch   5 | 700/708 batches | lr 0.00081 | ms/batch 46.05 | loss 106.61 | gep 52.47 |gepc 53.41 |dar  0.72 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   5 | time: 34.49s | valid loss 52.1031 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-Oct18-21-39
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:11<00:00, 69.28it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.666764
# ARI_cluster/label          0.710007
# ASW_label                  0.663498
# ASW_label/batch            0.824583
# PCR_batch                  0.328881
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.873434
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6635, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3289, ASW (batch): 0.8246, graph connectivity: 0.8734, graph iLISI: nan
# random masking at epoch   6, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   6 | 100/708 batches | lr 0.00077 | ms/batch 46.96 | loss 106.66 | gep 52.42 |gepc 53.52 |dar  0.72 |
# scGPT - INFO - | epoch   6 | 200/708 batches | lr 0.00077 | ms/batch 46.16 | loss 104.88 | gep 51.41 |gepc 52.76 |dar  0.71 |
# scGPT - INFO - | epoch   6 | 300/708 batches | lr 0.00077 | ms/batch 46.11 | loss 104.46 | gep 51.22 |gepc 52.56 |dar  0.69 |
# scGPT - INFO - | epoch   6 | 400/708 batches | lr 0.00077 | ms/batch 46.15 | loss 105.72 | gep 51.97 |gepc 53.06 |dar  0.69 |
# scGPT - INFO - | epoch   6 | 500/708 batches | lr 0.00077 | ms/batch 46.88 | loss 104.28 | gep 51.17 |gepc 52.41 |dar  0.70 |
# scGPT - INFO - | epoch   6 | 600/708 batches | lr 0.00077 | ms/batch 46.06 | loss 104.40 | gep 51.29 |gepc 52.41 |dar  0.70 |
# scGPT - INFO - | epoch   6 | 700/708 batches | lr 0.00077 | ms/batch 46.09 | loss 103.24 | gep 50.83 |gepc 51.74 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   6 | time: 34.45s | valid loss 52.4797 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   7, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   7 | 100/708 batches | lr 0.00074 | ms/batch 65.00 | loss 105.44 | gep 51.72 |gepc 53.01 |dar  0.71 |
# scGPT - INFO - | epoch   7 | 200/708 batches | lr 0.00074 | ms/batch 61.32 | loss 102.60 | gep 50.29 |gepc 51.61 |dar  0.70 |
# scGPT - INFO - | epoch   7 | 300/708 batches | lr 0.00074 | ms/batch 46.25 | loss 105.84 | gep 51.90 |gepc 53.25 |dar  0.69 |
# scGPT - INFO - | epoch   7 | 400/708 batches | lr 0.00074 | ms/batch 46.09 | loss 102.99 | gep 50.55 |gepc 51.73 |dar  0.72 |
# scGPT - INFO - | epoch   7 | 500/708 batches | lr 0.00074 | ms/batch 46.00 | loss 104.17 | gep 51.25 |gepc 52.20 |dar  0.73 |
# scGPT - INFO - | epoch   7 | 600/708 batches | lr 0.00074 | ms/batch 46.04 | loss 103.58 | gep 50.91 |gepc 51.96 |dar  0.71 |
# scGPT - INFO - | epoch   7 | 700/708 batches | lr 0.00074 | ms/batch 46.21 | loss 104.74 | gep 51.40 |gepc 52.61 |dar  0.73 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   7 | time: 37.67s | valid loss 51.1444 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 51.1444
# random masking at epoch   8, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   8 | 100/708 batches | lr 0.00070 | ms/batch 63.71 | loss 105.25 | gep 51.72 |gepc 52.84 |dar  0.69 |
# scGPT - INFO - | epoch   8 | 200/708 batches | lr 0.00070 | ms/batch 65.70 | loss 103.17 | gep 50.69 |gepc 51.77 |dar  0.71 |
# scGPT - INFO - | epoch   8 | 300/708 batches | lr 0.00070 | ms/batch 49.78 | loss 102.37 | gep 50.20 |gepc 51.47 |dar  0.70 |
# scGPT - INFO - | epoch   8 | 400/708 batches | lr 0.00070 | ms/batch 46.30 | loss 102.78 | gep 50.40 |gepc 51.69 |dar  0.70 |
# scGPT - INFO - | epoch   8 | 500/708 batches | lr 0.00070 | ms/batch 46.38 | loss 103.08 | gep 50.60 |gepc 51.79 |dar  0.69 |
# scGPT - INFO - | epoch   8 | 600/708 batches | lr 0.00070 | ms/batch 46.13 | loss 103.78 | gep 50.88 |gepc 52.19 |dar  0.71 |
# scGPT - INFO - | epoch   8 | 700/708 batches | lr 0.00070 | ms/batch 46.55 | loss 101.13 | gep 49.69 |gepc 50.71 |dar  0.73 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   8 | time: 38.45s | valid loss 53.1357 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch   9, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch   9 | 100/708 batches | lr 0.00066 | ms/batch 46.94 | loss 101.78 | gep 49.98 |gepc 51.08 |dar  0.72 |
# scGPT - INFO - | epoch   9 | 200/708 batches | lr 0.00066 | ms/batch 46.37 | loss 101.57 | gep 49.85 |gepc 50.99 |dar  0.74 |
# scGPT - INFO - | epoch   9 | 300/708 batches | lr 0.00066 | ms/batch 46.12 | loss 101.28 | gep 49.64 |gepc 50.93 |dar  0.71 |
# scGPT - INFO - | epoch   9 | 400/708 batches | lr 0.00066 | ms/batch 47.16 | loss 102.49 | gep 50.39 |gepc 51.41 |dar  0.69 |
# scGPT - INFO - | epoch   9 | 500/708 batches | lr 0.00066 | ms/batch 46.10 | loss 103.11 | gep 50.50 |gepc 51.90 |dar  0.71 |
# scGPT - INFO - | epoch   9 | 600/708 batches | lr 0.00066 | ms/batch 46.41 | loss 101.75 | gep 50.09 |gepc 51.00 |dar  0.66 |
# scGPT - INFO - | epoch   9 | 700/708 batches | lr 0.00066 | ms/batch 46.92 | loss 101.69 | gep 49.91 |gepc 51.11 |dar  0.67 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch   9 | time: 34.59s | valid loss 50.0050 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 50.0050
# random masking at epoch  10, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  10 | 100/708 batches | lr 0.00063 | ms/batch 46.76 | loss 102.78 | gep 50.62 |gepc 51.49 |dar  0.68 |
# scGPT - INFO - | epoch  10 | 200/708 batches | lr 0.00063 | ms/batch 46.33 | loss 100.66 | gep 49.47 |gepc 50.47 |dar  0.71 |
# scGPT - INFO - | epoch  10 | 300/708 batches | lr 0.00063 | ms/batch 45.98 | loss 99.95 | gep 49.05 |gepc 50.18 |dar  0.72 |
# scGPT - INFO - | epoch  10 | 400/708 batches | lr 0.00063 | ms/batch 46.31 | loss 100.58 | gep 49.39 |gepc 50.48 |dar  0.70 |
# scGPT - INFO - | epoch  10 | 500/708 batches | lr 0.00063 | ms/batch 46.12 | loss 102.02 | gep 50.15 |gepc 51.17 |dar  0.70 |
# scGPT - INFO - | epoch  10 | 600/708 batches | lr 0.00063 | ms/batch 46.21 | loss 100.71 | gep 49.55 |gepc 50.49 |dar  0.67 |
# scGPT - INFO - | epoch  10 | 700/708 batches | lr 0.00063 | ms/batch 46.86 | loss 101.20 | gep 49.70 |gepc 50.77 |dar  0.73 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  10 | time: 34.50s | valid loss 50.7140 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-Oct18-21-39
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:11<00:00, 66.25it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.790962
# ARI_cluster/label          0.940832
# ASW_label                  0.649485
# ASW_label/batch            0.829177
# PCR_batch                  0.399370
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.902561
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6495, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3994, ASW (batch): 0.8292, graph connectivity: 0.9026, graph iLISI: nan
# random masking at epoch  11, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  11 | 100/708 batches | lr 0.00060 | ms/batch 46.96 | loss 101.77 | gep 50.03 |gepc 51.07 |dar  0.67 |
# scGPT - INFO - | epoch  11 | 200/708 batches | lr 0.00060 | ms/batch 46.38 | loss 99.63 | gep 48.97 |gepc 49.97 |dar  0.69 |
# scGPT - INFO - | epoch  11 | 300/708 batches | lr 0.00060 | ms/batch 46.35 | loss 99.46 | gep 48.77 |gepc 50.01 |dar  0.68 |
# scGPT - INFO - | epoch  11 | 400/708 batches | lr 0.00060 | ms/batch 46.35 | loss 99.55 | gep 48.82 |gepc 50.02 |dar  0.71 |
# scGPT - INFO - | epoch  11 | 500/708 batches | lr 0.00060 | ms/batch 46.34 | loss 100.69 | gep 49.44 |gepc 50.53 |dar  0.71 |
# scGPT - INFO - | epoch  11 | 600/708 batches | lr 0.00060 | ms/batch 46.12 | loss 100.68 | gep 49.51 |gepc 50.49 |dar  0.68 |
# scGPT - INFO - | epoch  11 | 700/708 batches | lr 0.00060 | ms/batch 46.34 | loss 100.52 | gep 49.29 |gepc 50.52 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  11 | time: 34.52s | valid loss 50.1476 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  12, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  12 | 100/708 batches | lr 0.00057 | ms/batch 47.18 | loss 101.08 | gep 49.68 |gepc 50.72 |dar  0.68 |
# scGPT - INFO - | epoch  12 | 200/708 batches | lr 0.00057 | ms/batch 46.35 | loss 99.00 | gep 48.61 |gepc 49.70 |dar  0.68 |
# scGPT - INFO - | epoch  12 | 300/708 batches | lr 0.00057 | ms/batch 58.38 | loss 98.55 | gep 48.36 |gepc 49.48 |dar  0.72 |
# scGPT - INFO - | epoch  12 | 400/708 batches | lr 0.00057 | ms/batch 59.40 | loss 98.76 | gep 48.55 |gepc 49.52 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 500/708 batches | lr 0.00057 | ms/batch 58.59 | loss 99.43 | gep 48.84 |gepc 49.88 |dar  0.71 |
# scGPT - INFO - | epoch  12 | 600/708 batches | lr 0.00057 | ms/batch 58.63 | loss 99.51 | gep 48.89 |gepc 49.94 |dar  0.69 |
# scGPT - INFO - | epoch  12 | 700/708 batches | lr 0.00057 | ms/batch 58.37 | loss 99.76 | gep 49.03 |gepc 50.05 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  12 | time: 40.80s | valid loss 51.3144 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  13, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  13 | 100/708 batches | lr 0.00054 | ms/batch 64.15 | loss 100.37 | gep 49.33 |gepc 50.35 |dar  0.69 |
# scGPT - INFO - | epoch  13 | 200/708 batches | lr 0.00054 | ms/batch 64.09 | loss 97.38 | gep 47.75 |gepc 48.93 |dar  0.70 |
# scGPT - INFO - | epoch  13 | 300/708 batches | lr 0.00054 | ms/batch 59.97 | loss 98.72 | gep 48.53 |gepc 49.50 |dar  0.68 |
# scGPT - INFO - | epoch  13 | 400/708 batches | lr 0.00054 | ms/batch 46.42 | loss 98.35 | gep 48.25 |gepc 49.42 |dar  0.68 |
# scGPT - INFO - | epoch  13 | 500/708 batches | lr 0.00054 | ms/batch 46.41 | loss 97.75 | gep 48.01 |gepc 49.08 |dar  0.65 |
# scGPT - INFO - | epoch  13 | 600/708 batches | lr 0.00054 | ms/batch 47.05 | loss 98.20 | gep 48.29 |gepc 49.22 |dar  0.69 |
# scGPT - INFO - | epoch  13 | 700/708 batches | lr 0.00054 | ms/batch 46.40 | loss 99.69 | gep 49.02 |gepc 49.97 |dar  0.70 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  13 | time: 39.55s | valid loss 49.9826 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 49.9826
# random masking at epoch  14, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  14 | 100/708 batches | lr 0.00051 | ms/batch 46.97 | loss 99.85 | gep 49.11 |gepc 50.05 |dar  0.69 |
# scGPT - INFO - | epoch  14 | 200/708 batches | lr 0.00051 | ms/batch 46.30 | loss 97.34 | gep 47.76 |gepc 48.88 |dar  0.70 |
# scGPT - INFO - | epoch  14 | 300/708 batches | lr 0.00051 | ms/batch 46.16 | loss 98.84 | gep 48.59 |gepc 49.57 |dar  0.68 |
# scGPT - INFO - | epoch  14 | 400/708 batches | lr 0.00051 | ms/batch 46.45 | loss 97.67 | gep 47.88 |gepc 49.07 |dar  0.72 |
# scGPT - INFO - | epoch  14 | 500/708 batches | lr 0.00051 | ms/batch 46.65 | loss 97.45 | gep 47.77 |gepc 48.99 |dar  0.69 |
# scGPT - INFO - | epoch  14 | 600/708 batches | lr 0.00051 | ms/batch 46.49 | loss 99.40 | gep 48.81 |gepc 49.87 |dar  0.71 |
# scGPT - INFO - | epoch  14 | 700/708 batches | lr 0.00051 | ms/batch 47.50 | loss 97.40 | gep 47.83 |gepc 48.86 |dar  0.71 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  14 | time: 34.65s | valid loss 48.7023 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 48.7023
# random masking at epoch  15, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  15 | 100/708 batches | lr 0.00049 | ms/batch 47.40 | loss 99.37 | gep 48.78 |gepc 49.88 |dar  0.71 |
# scGPT - INFO - | epoch  15 | 200/708 batches | lr 0.00049 | ms/batch 46.38 | loss 96.97 | gep 47.53 |gepc 48.73 |dar  0.71 |
# scGPT - INFO - | epoch  15 | 300/708 batches | lr 0.00049 | ms/batch 46.20 | loss 97.53 | gep 47.94 |gepc 48.91 |dar  0.68 |
# scGPT - INFO - | epoch  15 | 400/708 batches | lr 0.00049 | ms/batch 46.34 | loss 96.34 | gep 47.32 |gepc 48.35 |dar  0.66 |
# scGPT - INFO - | epoch  15 | 500/708 batches | lr 0.00049 | ms/batch 46.26 | loss 98.50 | gep 48.37 |gepc 49.42 |dar  0.71 |
# scGPT - INFO - | epoch  15 | 600/708 batches | lr 0.00049 | ms/batch 46.29 | loss 97.37 | gep 47.86 |gepc 48.86 |dar  0.64 |
# scGPT - INFO - | epoch  15 | 700/708 batches | lr 0.00049 | ms/batch 46.19 | loss 96.73 | gep 47.50 |gepc 48.54 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  15 | time: 34.55s | valid loss 49.1982 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-Oct18-21-39
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:10<00:00, 71.90it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.772104
# ARI_cluster/label          0.919801
# ASW_label                  0.637356
# ASW_label/batch            0.848759
# PCR_batch                  0.384912
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.923960
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6374, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.3849, ASW (batch): 0.8488, graph connectivity: 0.9240, graph iLISI: nan
# random masking at epoch  16, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  16 | 100/708 batches | lr 0.00046 | ms/batch 54.54 | loss 99.08 | gep 48.64 |gepc 49.72 |dar  0.71 |
# scGPT - INFO - | epoch  16 | 200/708 batches | lr 0.00046 | ms/batch 46.91 | loss 98.03 | gep 48.10 |gepc 49.28 |dar  0.66 |
# scGPT - INFO - | epoch  16 | 300/708 batches | lr 0.00046 | ms/batch 46.74 | loss 95.73 | gep 46.96 |gepc 48.03 |dar  0.75 |
# scGPT - INFO - | epoch  16 | 400/708 batches | lr 0.00046 | ms/batch 47.17 | loss 96.59 | gep 47.34 |gepc 48.57 |dar  0.69 |
# scGPT - INFO - | epoch  16 | 500/708 batches | lr 0.00046 | ms/batch 46.69 | loss 96.63 | gep 47.41 |gepc 48.51 |dar  0.72 |
# scGPT - INFO - | epoch  16 | 600/708 batches | lr 0.00046 | ms/batch 46.40 | loss 97.38 | gep 47.85 |gepc 48.84 |dar  0.69 |
# scGPT - INFO - | epoch  16 | 700/708 batches | lr 0.00046 | ms/batch 46.33 | loss 97.70 | gep 47.97 |gepc 49.08 |dar  0.65 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  16 | time: 35.49s | valid loss 49.1442 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  17, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  17 | 100/708 batches | lr 0.00044 | ms/batch 47.15 | loss 97.73 | gep 48.01 |gepc 49.05 |dar  0.67 |
# scGPT - INFO - | epoch  17 | 200/708 batches | lr 0.00044 | ms/batch 46.56 | loss 97.46 | gep 47.82 |gepc 48.98 |dar  0.66 |
# scGPT - INFO - | epoch  17 | 300/708 batches | lr 0.00044 | ms/batch 46.76 | loss 96.47 | gep 47.31 |gepc 48.45 |dar  0.71 |
# scGPT - INFO - | epoch  17 | 400/708 batches | lr 0.00044 | ms/batch 46.23 | loss 96.14 | gep 47.24 |gepc 48.21 |dar  0.69 |
# scGPT - INFO - | epoch  17 | 500/708 batches | lr 0.00044 | ms/batch 46.30 | loss 97.58 | gep 47.97 |gepc 48.92 |dar  0.69 |
# scGPT - INFO - | epoch  17 | 600/708 batches | lr 0.00044 | ms/batch 46.19 | loss 96.13 | gep 47.21 |gepc 48.21 |dar  0.72 |
# scGPT - INFO - | epoch  17 | 700/708 batches | lr 0.00044 | ms/batch 46.73 | loss 97.47 | gep 47.93 |gepc 48.86 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  17 | time: 34.65s | valid loss 49.0224 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  18, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  18 | 100/708 batches | lr 0.00042 | ms/batch 46.59 | loss 96.78 | gep 47.49 |gepc 48.60 |dar  0.69 |
# scGPT - INFO - | epoch  18 | 200/708 batches | lr 0.00042 | ms/batch 46.25 | loss 95.55 | gep 46.87 |gepc 48.00 |dar  0.67 |
# scGPT - INFO - | epoch  18 | 300/708 batches | lr 0.00042 | ms/batch 46.48 | loss 97.20 | gep 47.68 |gepc 48.82 |dar  0.71 |
# scGPT - INFO - | epoch  18 | 400/708 batches | lr 0.00042 | ms/batch 46.40 | loss 95.88 | gep 47.09 |gepc 48.12 |dar  0.67 |
# scGPT - INFO - | epoch  18 | 500/708 batches | lr 0.00042 | ms/batch 46.51 | loss 96.11 | gep 47.21 |gepc 48.19 |dar  0.71 |
# scGPT - INFO - | epoch  18 | 600/708 batches | lr 0.00042 | ms/batch 46.37 | loss 95.02 | gep 46.68 |gepc 47.63 |dar  0.70 |
# scGPT - INFO - | epoch  18 | 700/708 batches | lr 0.00042 | ms/batch 46.44 | loss 96.24 | gep 47.30 |gepc 48.28 |dar  0.65 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  18 | time: 34.53s | valid loss 49.1206 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  19, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  19 | 100/708 batches | lr 0.00040 | ms/batch 46.88 | loss 96.95 | gep 47.54 |gepc 48.74 |dar  0.67 |
# scGPT - INFO - | epoch  19 | 200/708 batches | lr 0.00040 | ms/batch 46.08 | loss 95.77 | gep 47.02 |gepc 48.05 |dar  0.70 |
# scGPT - INFO - | epoch  19 | 300/708 batches | lr 0.00040 | ms/batch 47.05 | loss 96.86 | gep 47.49 |gepc 48.65 |dar  0.72 |
# scGPT - INFO - | epoch  19 | 400/708 batches | lr 0.00040 | ms/batch 46.57 | loss 95.52 | gep 46.84 |gepc 47.97 |dar  0.72 |
# scGPT - INFO - | epoch  19 | 500/708 batches | lr 0.00040 | ms/batch 46.25 | loss 96.09 | gep 47.14 |gepc 48.23 |dar  0.72 |
# scGPT - INFO - | epoch  19 | 600/708 batches | lr 0.00040 | ms/batch 46.21 | loss 95.53 | gep 46.93 |gepc 47.95 |dar  0.65 |
# scGPT - INFO - | epoch  19 | 700/708 batches | lr 0.00040 | ms/batch 46.30 | loss 96.47 | gep 47.35 |gepc 48.45 |dar  0.66 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  19 | time: 34.57s | valid loss 49.3791 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  20, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  20 | 100/708 batches | lr 0.00038 | ms/batch 63.17 | loss 97.28 | gep 47.70 |gepc 48.84 |dar  0.73 |
# scGPT - INFO - | epoch  20 | 200/708 batches | lr 0.00038 | ms/batch 63.83 | loss 94.76 | gep 46.45 |gepc 47.62 |dar  0.69 |
# scGPT - INFO - | epoch  20 | 300/708 batches | lr 0.00038 | ms/batch 48.43 | loss 96.20 | gep 47.23 |gepc 48.26 |dar  0.71 |
# scGPT - INFO - | epoch  20 | 400/708 batches | lr 0.00038 | ms/batch 46.25 | loss 96.23 | gep 47.35 |gepc 48.23 |dar  0.65 |
# scGPT - INFO - | epoch  20 | 500/708 batches | lr 0.00038 | ms/batch 46.22 | loss 94.84 | gep 46.62 |gepc 47.53 |dar  0.70 |
# scGPT - INFO - | epoch  20 | 600/708 batches | lr 0.00038 | ms/batch 46.92 | loss 96.31 | gep 47.26 |gepc 48.35 |dar  0.69 |
# scGPT - INFO - | epoch  20 | 700/708 batches | lr 0.00038 | ms/batch 46.18 | loss 95.12 | gep 46.72 |gepc 47.72 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  20 | time: 38.11s | valid loss 47.8895 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 47.8895
# scGPT - INFO - Saving model to save/dev_BMMC-Oct18-21-39
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:12<00:00, 62.96it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.735496
# ARI_cluster/label          0.853957
# ASW_label                  0.643390
# ASW_label/batch            0.871946
# PCR_batch                  0.410969
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.945513
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6434, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4110, ASW (batch): 0.8719, graph connectivity: 0.9455, graph iLISI: nan
# random masking at epoch  21, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  21 | 100/708 batches | lr 0.00036 | ms/batch 61.85 | loss 94.97 | gep 46.55 |gepc 47.68 |dar  0.75 |
# scGPT - INFO - | epoch  21 | 200/708 batches | lr 0.00036 | ms/batch 55.51 | loss 94.77 | gep 46.51 |gepc 47.60 |dar  0.67 |
# scGPT - INFO - | epoch  21 | 300/708 batches | lr 0.00036 | ms/batch 46.19 | loss 95.06 | gep 46.56 |gepc 47.81 |dar  0.69 |
# scGPT - INFO - | epoch  21 | 400/708 batches | lr 0.00036 | ms/batch 46.25 | loss 94.84 | gep 46.54 |gepc 47.59 |dar  0.70 |
# scGPT - INFO - | epoch  21 | 500/708 batches | lr 0.00036 | ms/batch 46.37 | loss 96.40 | gep 47.32 |gepc 48.40 |dar  0.68 |
# scGPT - INFO - | epoch  21 | 600/708 batches | lr 0.00036 | ms/batch 46.35 | loss 94.51 | gep 46.44 |gepc 47.36 |dar  0.71 |
# scGPT - INFO - | epoch  21 | 700/708 batches | lr 0.00036 | ms/batch 46.64 | loss 96.00 | gep 47.13 |gepc 48.18 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  21 | time: 37.03s | valid loss 47.6024 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 47.6024
# random masking at epoch  22, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  22 | 100/708 batches | lr 0.00034 | ms/batch 47.01 | loss 95.59 | gep 46.94 |gepc 47.95 |dar  0.70 |
# scGPT - INFO - | epoch  22 | 200/708 batches | lr 0.00034 | ms/batch 47.10 | loss 95.14 | gep 46.74 |gepc 47.75 |dar  0.66 |
# scGPT - INFO - | epoch  22 | 300/708 batches | lr 0.00034 | ms/batch 46.59 | loss 93.76 | gep 46.02 |gepc 47.03 |dar  0.72 |
# scGPT - INFO - | epoch  22 | 400/708 batches | lr 0.00034 | ms/batch 46.49 | loss 94.30 | gep 46.30 |gepc 47.33 |dar  0.67 |
# scGPT - INFO - | epoch  22 | 500/708 batches | lr 0.00034 | ms/batch 46.50 | loss 95.00 | gep 46.65 |gepc 47.64 |dar  0.71 |
# scGPT - INFO - | epoch  22 | 600/708 batches | lr 0.00034 | ms/batch 46.56 | loss 94.69 | gep 46.49 |gepc 47.52 |dar  0.68 |
# scGPT - INFO - | epoch  22 | 700/708 batches | lr 0.00034 | ms/batch 46.53 | loss 95.94 | gep 47.07 |gepc 48.18 |dar  0.68 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  22 | time: 34.68s | valid loss 47.3449 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 47.3449
# random masking at epoch  23, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  23 | 100/708 batches | lr 0.00032 | ms/batch 47.84 | loss 95.72 | gep 46.96 |gepc 48.07 |dar  0.69 |
# scGPT - INFO - | epoch  23 | 200/708 batches | lr 0.00032 | ms/batch 46.49 | loss 94.48 | gep 46.33 |gepc 47.44 |dar  0.70 |
# scGPT - INFO - | epoch  23 | 300/708 batches | lr 0.00032 | ms/batch 46.25 | loss 93.34 | gep 45.82 |gepc 46.83 |dar  0.68 |
# scGPT - INFO - | epoch  23 | 400/708 batches | lr 0.00032 | ms/batch 46.44 | loss 95.59 | gep 46.92 |gepc 47.98 |dar  0.68 |
# scGPT - INFO - | epoch  23 | 500/708 batches | lr 0.00032 | ms/batch 47.01 | loss 94.66 | gep 46.52 |gepc 47.45 |dar  0.70 |
# scGPT - INFO - | epoch  23 | 600/708 batches | lr 0.00032 | ms/batch 46.31 | loss 93.95 | gep 46.13 |gepc 47.11 |dar  0.71 |
# scGPT - INFO - | epoch  23 | 700/708 batches | lr 0.00032 | ms/batch 46.57 | loss 95.87 | gep 47.06 |gepc 48.12 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  23 | time: 34.72s | valid loss 47.7477 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# random masking at epoch  24, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  24 | 100/708 batches | lr 0.00031 | ms/batch 46.92 | loss 95.19 | gep 46.74 |gepc 47.76 |dar  0.68 |
# scGPT - INFO - | epoch  24 | 200/708 batches | lr 0.00031 | ms/batch 46.53 | loss 94.81 | gep 46.55 |gepc 47.58 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 300/708 batches | lr 0.00031 | ms/batch 46.21 | loss 95.61 | gep 46.83 |gepc 48.07 |dar  0.72 |
# scGPT - INFO - | epoch  24 | 400/708 batches | lr 0.00031 | ms/batch 47.76 | loss 93.62 | gep 46.05 |gepc 46.91 |dar  0.66 |
# scGPT - INFO - | epoch  24 | 500/708 batches | lr 0.00031 | ms/batch 46.71 | loss 94.28 | gep 46.31 |gepc 47.29 |dar  0.67 |
# scGPT - INFO - | epoch  24 | 600/708 batches | lr 0.00031 | ms/batch 46.40 | loss 93.55 | gep 45.99 |gepc 46.89 |dar  0.68 |
# scGPT - INFO - | epoch  24 | 700/708 batches | lr 0.00031 | ms/batch 46.36 | loss 94.57 | gep 46.40 |gepc 47.48 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  24 | time: 34.73s | valid loss 47.0392 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Best model with score 47.0392
# random masking at epoch  25, ratio of masked values in train:  0.3988
# scGPT - INFO - | epoch  25 | 100/708 batches | lr 0.00029 | ms/batch 47.33 | loss 94.85 | gep 46.55 |gepc 47.63 |dar  0.67 |
# scGPT - INFO - | epoch  25 | 200/708 batches | lr 0.00029 | ms/batch 46.37 | loss 93.23 | gep 45.80 |gepc 46.74 |dar  0.70 |
# scGPT - INFO - | epoch  25 | 300/708 batches | lr 0.00029 | ms/batch 46.28 | loss 94.40 | gep 46.35 |gepc 47.39 |dar  0.66 |
# scGPT - INFO - | epoch  25 | 400/708 batches | lr 0.00029 | ms/batch 46.22 | loss 93.60 | gep 45.94 |gepc 46.97 |dar  0.69 |
# scGPT - INFO - | epoch  25 | 500/708 batches | lr 0.00029 | ms/batch 46.25 | loss 94.76 | gep 46.53 |gepc 47.57 |dar  0.67 |
# scGPT - INFO - | epoch  25 | 600/708 batches | lr 0.00029 | ms/batch 46.23 | loss 94.25 | gep 46.29 |gepc 47.28 |dar  0.68 |
# scGPT - INFO - | epoch  25 | 700/708 batches | lr 0.00029 | ms/batch 46.20 | loss 94.89 | gep 46.62 |gepc 47.58 |dar  0.69 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - | end of epoch  25 | time: 34.54s | valid loss 47.4910 |
# scGPT - INFO - -----------------------------------------------------------------------------------------
# scGPT - INFO - Saving model to save/dev_BMMC-Oct18-21-39
# scGPT - INFO - Evaluating cls cell embeddings
# 100%|██████████| 787/787 [00:11<00:00, 71.31it/s]
# NMI...
# ARI...
# Silhouette score...
# PC regression...
# Graph connectivity...
# scGPT - INFO -                                   0
# NMI_cluster/label          0.776199
# ARI_cluster/label          0.921540
# ASW_label                  0.632463
# ASW_label/batch            0.871329
# PCR_batch                  0.421968
# cell_cycle_conservation         NaN
# isolated_label_F1               NaN
# isolated_label_silhouette       NaN
# graph_conn                 0.934274
# kBET                            NaN
# iLISI                           NaN
# cLISI                           NaN
# hvg_overlap                     NaN
# trajectory                      NaN
# scGPT - INFO - Biological Conservation Metrics:
# ASW (cell-type): 0.6325, graph cLISI: nan, isolated label silhouette: nan,
# Batch Effect Removal Metrics:
# PCR_batch: 0.4220, ASW (batch): 0.8713, graph connectivity: 0.9343, graph iLISI: nan

# %%
# save the best model
torch.save(best_model.state_dict(), save_dir / "best_model.pt")

# %%
artifact = wandb.Artifact(f"best_model", type="model")
glob_str = os.path.join(save_dir, "best_model.pt")
artifact.add_file(glob_str)
run.log_artifact(artifact)

run.finish()
wandb.finish()
gc.collect()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>▁█▇▅▇</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▂▃▃▃▄▄▄▅▅▅▅▆▆▆▇▇▇▇██</td></tr><tr><td>test/ARI_cluster/label</td><td>▁█▇▅▇</td></tr><tr><td>test/ASW_label</td><td>█▅▂▃▁</td></tr><tr><td>test/ASW_label/batch</td><td>▁▂▅██</td></tr><tr><td>test/NMI_cluster/label</td><td>▁█▇▅▇</td></tr><tr><td>test/PCR_batch</td><td>▁▆▅▇█</td></tr><tr><td>test/avg_bio</td><td>▁█▇▅▇</td></tr><tr><td>test/best_model_epoch</td><td>▁▃▅▇█</td></tr><tr><td>test/graph_conn</td><td>▁▄▆█▇</td></tr><tr><td>train/dab</td><td>█▂▁▅▁▄▄▃▄▅▂▆▄▃▅▄▁▂▂▇▃▄▄▄▃▂▃▅▄▅▃▄▄▄▃▂▃▃▃▅</td></tr><tr><td>train/gep</td><td>▇▅▅▂▄▃█▄▅▄▄▃▂▄▃▂▃▄▄▂▃▂▃▂▃▄▂▂▂▁▃▂▁▃▃▃▃▂▂▃</td></tr><tr><td>train/mvc</td><td>█▄▄▂▄▃▇▃▄▃▃▃▂▃▃▂▂▃▄▂▂▂▃▂▃▄▂▂▂▁▂▂▁▃▃▃▃▂▂▂</td></tr><tr><td>valid/loss</td><td>█▇▇▄▅▅▄▅▃▄▃▄▃▂▃▂▂▂▃▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_bio</td><td>0.77673</td></tr><tr><td>epoch</td><td>25</td></tr><tr><td>test/ARI_cluster/label</td><td>0.92154</td></tr><tr><td>test/ASW_label</td><td>0.63246</td></tr><tr><td>test/ASW_label/batch</td><td>0.87133</td></tr><tr><td>test/NMI_cluster/label</td><td>0.7762</td></tr><tr><td>test/PCR_batch</td><td>0.42197</td></tr><tr><td>test/best_model_epoch</td><td>24</td></tr><tr><td>test/graph_conn</td><td>0.93427</td></tr><tr><td>train/dab</td><td>0.57504</td></tr><tr><td>train/gep</td><td>44.45348</td></tr><tr><td>train/mvc</td><td>45.66718</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">atomic-jazz-449</strong> at: <a href='https://wandb.ai/scformer/scGPT/runs/lrpm65jz' target="_blank">https://wandb.ai/scformer/scGPT/runs/lrpm65jz</a><br/>Synced 5 W&B file(s), 10 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20231018_213957-lrpm65jz/logs</code>
# 92987
